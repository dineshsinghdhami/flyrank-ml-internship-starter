# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dineshsinghdhami/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Lane 2: Refresh / Content Opportunity Scoring
#
# I chose this lane because I want to learn how to identify which pages should be reviewed first using signals such as visibility, decline, CTR, position, and content age. It also connects well with the starter notebooks I already completed, so it is a good direction for me to continue learning.

# %%
lane = "Refresh / Content Opportunity Scoring"
print("Chosen lane:", lane)
# Out:
# Chosen lane: Refresh / Content Opportunity Scoring

# %% [markdown]
# Decision: Which pages should be reviewed first for refresh or improvement?
#
# Action: A content or SEO team can use the ranked results to decide which pages to check first.
#
# Cost of a wrong call: If the system recommends the wrong page, time may be wasted reviewing or changing content that did not need attention, while a more important page may be missed.

# %%
decision = "Review the pages that may need refresh or improvement first"
action = "A content or SEO team checks the ranked pages"
wrong_call_cost = "Time may be wasted on the wrong page while a more important page is missed"

print("Decision:", decision)
print("Action:", action)
print("Cost of a wrong call:", wrong_call_cost)
# Out:
# Decision: Review the pages that may need refresh or improvement first
# Action: A content or SEO team checks the ranked pages
# Cost of a wrong call: Time may be wasted on the wrong page while a more important page is missed

# %% [markdown]
# The starter dataset contains 30,000 rows. The average number of impressions over 90 days is about 5,200, and the average CTR is 0.5107. These numbers show that there is enough search and visibility data to study which pages may deserve review first.

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/dineshsinghdhami/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv")
print("Total rows:", len(df))
print("Average impressions_90d:", round(df["impressions_90d"].mean(), 2))
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Total rows: 30000
# Average impressions_90d: 5200.37
# Average CTR: 0.5107

# %% [markdown]
# What I can claim: I can describe patterns observed in the data and use them to support decisions about which pages may deserve review first.
#
# What I cannot claim: I cannot prove that changing or refreshing a page will cause better results. I also cannot claim that this work predicts Google's algorithm or guarantees future traffic.

# %%
can_claim = "Observed patterns can support decisions about which pages may deserve review first."
cannot_claim = "This work cannot prove that refreshing a page causes better results or predict Google's algorithm."

print("Can claim:", can_claim)
print("Cannot claim:", cannot_claim)
# Out:
# Can claim: Observed patterns can support decisions about which pages may deserve review first.
# Cannot claim: This work cannot prove that refreshing a page causes better results or predict Google's algorithm.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
